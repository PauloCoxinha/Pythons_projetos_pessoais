# %%
import pandas as pd
import numpy as np

df_vendas = pd.read_csv('train.csv', encoding="utf-8", sep=",", low_memory=False)
display(list(df_vendas.columns))
display(df_vendas.sample(50))
display(df_vendas.describe())
display(df_vendas.info())
display(df_vendas.isna().sum())
df_vendas[df_vendas["Postal Code"].isnull()]
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales']
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1283    1284  CA-2018-122154  09/04/2018  11/04/2018     First Class
# 3693    3694  US-2016-131359  30/10/2016  02/11/2016    Second Class
# 1365    1366  US-2018-155425  10/11/2018  11/11/2018     First Class
# 5954    5955  CA-2015-155796  11/11/2015  15/11/2015    Second Class
# 4767    4768  CA-2016-123155  09/03/2016  12/03/2016     First Class
# 1214    1215  US-2018-118087  09/09/2018  13/09/2018  Standard Class
# 5247    5248  US-2016-168914  21/05/2016  27/05/2016  Standard Class
# 3323    3324  CA-2016-120810  23/07/2016  27/07/2016  Standard Class
# 740      741  CA-2015-112326  04/01/2015  08/01/2015  Standard Class
# ...
